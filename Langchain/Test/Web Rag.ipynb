# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain.document_loaders import WebBaseLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_experimental.text_splitter import SemanticChunker
from langchain_openai import OpenAIEmbeddings

# %%
loader = WebBaseLoader("https://www.sac.or.kr/site/main/show/show_view?SN=64761")

# 뉴스기사의 본문을 Chunk 단위로 쪼갬
text_splitter = CharacterTextSplitter(        
    separator="\n\n",
    chunk_size=3000,     # 쪼개는 글자수
    chunk_overlap=300,   # 오버랩 글자수
    length_function=len,
    is_separator_regex=False,
)
text_splitter = SemanticChunker(OpenAIEmbeddings())

# %%
# 웹사이트 내용 크롤링 후 Chunk 단위로 분할
docs = loader.load_and_split(text_splitter)
docs
# Out:
# [Document(metadata={'source': 'https://www.sac.or.kr/site/main/show/show_view?SN=64761', 'title': '상세 정보 | 공연·전시 | 예술의전당', 'description': '예술의전당', 'language': 'ko'}, page_content='\n\n\n\n\n\n\n\n\n\n상세 정보 | 공연·전시 | 예술의전당\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n \n\n\n\n\n\n\n\n\n\n\n\nENG\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                        오페라하우스 \n                    \n\n\n\n                        음악당\n                    \n\n\n\n                        미술관·박물관\n                    \n\n\n\n                        아카데미\n                    \n\n\n\n                        방문·이용\n                    \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t                   \t로그인\n\t                \n\n\t                    회원가입\n\t                \n\n공연·전시오페라하우스음악당미술관·박물관연간일정오늘의 공연·전시진행/예정 프로그램SAC 기획 프로그램패키지티켓오픈공지당일할인티켓예매·취소 안내서예아카이브아카데미아카데미 안내수강신청오디션신청나의강좌온라인 사군자아카데미 공지사항아카데미 FAQ방문·이용공간소개오시는 길·주차안내편의서비스입점매장전당소식고객센터세계음악분수(선곡표)포스트/웹진/매거진관람평관람예절SAC 투어예술의전당 SNS대관안내공간별 대관안내입장권 운영안내회원서비스로그인회원가입멤버십이벤트기관소개기관소개 메인예술의전당 소개특별사업정보공개후원하기마이페이지티켓예매내역강좌신청내역마이찜참여와활동개인정보관리나의멤버십후원회회원탈퇴\n공연·전시오페라하우스음악당미술관·박물관연간일정오늘의 공연·전시진행/예정 프로그램SAC 기획 프로그램패키지티켓오픈공지당일할인티켓예매·취소 안내서예아카이브아카데미아카데미 안내아카데미메인인문·감상미술실기서화어린이음악영재키즈클래식수강신청오디션신청나의강좌온라인 사군자아카데미 공지사항아카데미 FAQ방문·이용공간소개공간안내공연장전시장공연영상스튜디오-실감야외공간홍보관(@700)사이버투어오시는 길·주차안내편의서비스공연장 편의서비스전시장 편의서비스장애인·국가유공자 이용안내입점매장음식점쇼핑전당소식공지사항보도자료채용공고고객센터서비스플라자유실물센터FAQ1:1문의하기세계음악분수(선곡표)포스트/웹진/매거진관람평최대 별점 공연/전시최신순평점 높은순관람예절SAC 투어예술의전당 SNS대관안내공간별 대관안내오페라하우스음악당미술관·박물관공연영상스튜디오-실감기타 행사공간 및 촬영장소입장권 운영안내입장권 운영안내공간별 특이사항 및 좌석 안내공연·전시 홍보 서비스 안내배너광고 신청 안내회원서비스로그인회원가입멤버십이벤트기관소개기관소개 메인예술의전당 소개인사말역사운영이념조직CI소개협력기관후원회특별사업SAC ON SCREEN객석기부문화햇살사업정보공개정보공개안내사전정보공표비공개 대상정보공공데이터 개방경영공시사업실명제사업실명제운영보고서기부금 활용 내역후원하기마이페이지티켓예매내역강좌신청내역수강신청오디션내역수강생정보마이찜참여와활동개인정보관리나의멤버십후원회회원탈퇴\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n검색하기\n\n\n\n\n\n \n\n\n\n닫기\n\n\n\n\n\n\n\n\n \n\n오늘의행사\n\n\n\n\n챗봇\n\n\n\n\nTOP\n\n\n\n\n\n\n\n\n\n\n\n\n\n찜하기\n공동주최\n\n\r\n              \t 비욘드 더 스크림\r\n                에드바르 뭉크\n\n\n기간\r\n                    \r\n                        \r\n                        \r\n                            2024-05-22(수) ~ 2024-09-19(목)\r\n                        \r\n                    \r\n                    \n시간10:00 ~ 19:00 (※ 매주 월요일 휴관)\n장소\n\r\n                            한가람미술관 제1전시실,  제2전시실\r\n                        \n\n입장연령전체관람\n전시입장마감시간18:10\n가격성인 20,000원 / 청소년,어린이 15,000원\n주최서울신문사, KBS미디어, 예술의전당\n후원문화체육관광부, 주한 노르웨이 대사관\n문의070-8843-2024\n\n#에드바르뭉크 \xa0#비욘드더스크림 \xa0#120주년 \xa0#절규 \xa0#예술의전당 \xa0#뭉크 \xa0\n\n\n\n\n\n\n\n예매\n\n\n\n\n\n\n\n\n\n\n공연·전시공연·전시아카데미방문·이용대관안내회원서비스기관소개마이페이지이용안내상세 정보오페라하우스음악당미술관·박물관연간일정오늘의 공연·전시진행/예정 프로그램SAC 기획 프로그램패키지티켓오픈공지당일할인티켓예매·취소 안내서예아카이브\n\n\n국EN\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0\xa0>\xa0\xa0공연/전시\xa0\xa0>\xa0\xa0진행·예정 프로그램\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n작품소개\n할인정보\n장소안내\n관람평(1)\n예매안내\n\n\n\n\n\n\n\n\n\u200a노르웨이의 국민화가이자 표현주의의 선구자 에드바르 뭉크(1863-1944)의 작품 140점을 소개하는\n\u200a아시아 최대 규모 회고전이 5월 22일부터 9월 19일까지 예술의전당 한가람미술관 1층에서 열립니다. ※ 현장에서 티켓 수령 시 할인에 해당하는 증빙자료(학생증, 신분증, 복지카드, 유공자증 등)를 제시하지 못할경우 차액 지불 후 전시 관람 가능\u200a\u200a[예술의전당 유료회원]\u200a성인 18,000원 / 청소년, 어린이: 13,000원 - 골드\xa0·\xa0블루·\xa0그린 · 예술의전당 우리V카드 회원 (1인 2매)\n\u200a\u200a[특별할인]\u200a1인 입장권: 10,000원\u200a- 65세 이상\xa0 - 장애인 복지카드 소지자 (1급~3급/중증) 본인 및 동반 1인\xa0 - 장애인 복지카드 소지자 (4급~6급/경증) 본인\xa0 - 국가유공자증, 의상자(1~2급)증 / 소지자 본인\xa0\xa0 - 유족증 (국가유공자,의사자), 의상자(3급이하)증 / 소지자 본인\xa0\u200a\u200a[현장할인]\u200a-\xa0군경소방관 본인 및 동반 1인 30% 할인\n\n\n\n\n\n\n\n\n소개\n공간 평면도\n\n\n\n\n\n\n\n본관 전체 3층 총 6개 전시실\n\n10:00 ~ 19:00\n매주월요일 휴관\n\n\n\n\n\n\n\n\n\n한가람미술관예술의전당에서 진행되는 다른 공간들 보다 편안하게 즐길 수 있는 열린 공간\n1990년에 문을 연 한가람미술관은 조형예술 전시를 위한 최적의 공간이다. 2003년 리노베이션을 거쳐 최신의 설비로 재탄생 하였다. 지하 1층 지상 3층 건물에 6개의 전시장과 수장고를 가지고 있으며,\r\n자연채광에 가까운 광천정 시스템으로 편안한 관람 분위기를 조성한다. 매년 50여 건이 넘는 전시행사가 개최되고 있으며\r\n그 내용은 고대문명을 소개하는 전시회부터 현대 미술까지 아우르고 있다. 예술의전당이 기획하여 주최한 주요 전시는\r\n<반 아파르트헤이트전>, <유럽공동 ...
#  Document(metadata={'source': 'https://www.sac.or.kr/site/main/show/show_view?SN=64761', 'title': '상세 정보 | 공연·전시 | 예술의전당', 'description': '예술의전당', 'language': 'ko'}, page_content='※ 저속한 표현, 타인의 명예훼손, 광고성 게시물 등은 통보 없이 삭제할 수 있음을 양지하여 주십시오.※ 등록된 관람평의 수정과 삭제는 마이페이지 > 참여와활동 > 관람평 에서 가능합니다. 관람평쓰기\n\n\n\n\n\n\n\n\n\n\n\n\n\nhappydanuk***\n2024.07.21(일) \n\n\n작품들은 최고 관람진행은 바보!! 6시50분까지 오디오반납하라고 계속 소리 고래고래 지름. 안에 진행요원들 많던데 입구에서 수거를 하던가 퇴근을 좀 늦게 하던가! 너무 짜증났음!! 1\n\n\n\n\n\n\n\n예매 및 환불·변경안내\n예술의전당은 초등학생 이상부터 공연 관람이 가능하며, 관람 연령 증빙이 어려울 경우 티켓 소지 여부 및 보호자의 동반 여부와 관계 없이 입장이 불가능합니다. (단, 어린이 대상 공연은 제외)\n\r\n승용차 이용 시 주차장이 혼잡하여 공연장 정시 입장이 어려울 수 있으니, 대중교통을 이용해 주시기 바랍니다. (주차장 혼잡으로 인한\xa0공연장 입장 지연 시 피해보상(티켓교환 및 환불)불가)\n\r\n온라인(PC,모바일) 예매의 경우 1회 10매까지 구매 가능합니다. 반복하여 예매하기 불편하거나 단체 티켓예매를 원하시면 서비스플라자 (1668-1352)를 이용해 주시기 바랍니다. 티켓은 유가증권이므로 분실하였을 경우 재발행 되지 않으며 환불 및 변경이 불가하오니 보관에 유의해주시기 바랍니다. 지정예매처를 통하지 않고 개인적으로 양도 양수한 티켓에 대해 예술의전당은 책임을 지지 않습니다. 공연, 전시에 따라 예매, 환불 및 환불수수료 정책이 상이할 경우 상세페이지에 별도 공지하며 해당 공지는 위 내용보다 우선합니다. 반드시 상세페이지를 확인 부탁드립니다. 환불·변경 수수료\n\n환불·변경 수수료\n\n\n\n\n\n\n\n\n구분\n환불수수료\n비고\n\n\n\n\n관람일 10일 전\n전액 환불\n\xa0\n\n\n관람일 9일~1일 전\n티켓금액의 10%\n관람일 3일 전 예매건에 한해\r\n\t\t\t예매당일 환불할 경우\r\n\t\t\t별도의 수수료 없이 환불 가능\n(전화 : 20:00까지 /\r\n\t\t\t방문 : 화~일 20:00까지, 월 18:00까지 /\r\n\t\t\t인터넷 23:59까지)\n\n\n관람 당일\n전당기획공연\n티켓금액의 90%\n공연시작 2시간 전까지\r\n\t\t\t(현장매표소 환불 불가)\n\n\n대관공연\n환불 불가\n관람일 1일 전까지 가능\n\n\n\n\n\n\r\n※ 전시 상품 취소수수료 규정\r\n- 전시 회차상품 : 예술의전당 대관 공연 기준 수수료 적용\r\n- 전시 상시상품 : 예매 후 7일까지 미부과, 8일부터 10% 부과 \n\n티켓예매 시 결제수단 \n\n\n 신용카드\n관람당일까지 사용 가능\n\n* 온라인(PC/모바일) 예매\n* 관람당일 현장매표소\n* 서비스플라자 방문구매\n\n\n 무통장(가상계좌입금)\n관람일 4일까지 사용 가능\n\n* 홈페이지(PC/모바일) 예매\n\n\n\n\n결제수단별 환불처리 ※ 티켓예매시 사용한 결제수단으로만 환불됩니다. 신용카드\n카드사 승인취소\n\n* 취소요청 후 4~5일내 취소\n* 카드사환불기준에따라다름\n* 체크카드 동일\n* 취소수수료는 재승인 필요\n\n\n 무통장(가상계좌입금)\n예매자명의 계좌로 환급\n\n* 취소요청 후 2일내 환급\n* 은행 영업일 기준\n* 실시간 계좌이체 불가\n* 취소수수료는 제외하고 환급\n\n\n\n\n\n예매취소 방법안내\n\n\n 홈페이지 예매\n- [ 마이페이지 > 티켓예매내역 ] 에서 직접 예매내역 조회 후 취소\r\n\t- 서비스플라자(1668-1352)를 통해 예매 취소 요청\n\n 전화 예매\n[ 마이페이지 > 티켓예매내역 ] 에서 직접 취소하거나\r\n\t서비스플라자(1668-1352)를 통해 취소 요청\n\n 예매 후 티켓 소지하고 있는 경우(방문예매, 우편배송 등)\n해당공연 관람일 1일전까지 비타민스테이션 서비스플라자로 직접 방문하여 티켓을 반납 하여야만 환불 가능\r\n\t방문 가능시간 (월- 09:00~18:00 / 화~일- 09:00~20:00)\r\n\t(자세한 문의는 고객센터로 문의 요망 : 1668-1352, 09:00~20:00)\n\n\n※ 부분취소\n\n기본적으로 부분취소 가능합니다. 단, 기프트 카드 등을 사용하여 결제한 경우에는 부분취소를 하실 수 없고, 전체취소만 가능합니다. 1+1, 3인 할인 등 특정 매수 제한이 있는 할인권종으로 예매하신 경우 부분취소를 하실 수 없고, 전체취소만 가능합니다. 예매 내역에 따라 부분 취소 가능여부가 달라지오니 서비스플라자 콜센터(1668-1352)로 문의해 주시기 바랍니다. 티켓수령 안내\n\n\n 현장매표소\n\n* 공연당일 수령\n* 공연시작 1시간 30분전부터 중간휴식시간까지\n* 중간휴식이 없는 경우 공연시작 후 30분까지 운영\n\n\n 서비스플라자\n\n* 위치 : 비타민스테이션 내\n* 운영시간 : 09:00~20:00, 월요일의 경우 09:00~18:00\n* 문의 : 1668-1352(연중무휴)\n* 타예매처 티켓 수령불가\n\n\n 우편 배송 신청\n\n* 배송신청 : 온라인,전화예매 시 공연일 14일전까지\n* 이용료 : 1회 배송시 3,200원 선결제\n* 수령일 : 배송신청 후 5일 이내 수령 (영업일 기준)\n\n\n\n\n 티켓수령시 유의사항\n\n증빙이 필요한 할인(쿠폰, 장애인 및 국가유공자, 학생, 문화릴레이, 당일할인티켓 등)의 경우, 본인이 직접 증빙자료를 제시하여야 수령이 가능합니다. 제시하지 못할 경우, 할인 받은 만큼 차액을 지불하시면 관람이 가능합니다. 공연 시작 직전에는 현장매표소가 매우 혼잡하오니 되도록 공연 30분전까지 티켓을 수령 해주시기 바랍니다. 목록보기\n\n\n\n\n\n관람평쓰기 \n\n\n\n\n관람평쓰기\n\n\n\n\n\n\n작성자\n비회원손님 2024.08.26(월)\n\n\n작품명\n에드바르 뭉크\n\n\n종합평점 *\n\n\n\n\n\n0\n\n\n\n\n\n관람평\n\n\n\n내용\n\n(0 / 최대 1000자) 관람평은 1000자까지만 등록이 가능합니다. 작품만족도작품성, 완성도, 무대, 출연자 등\n\n\n\n\n0\n\n\n\n\n관람비용 만족도가격, 할인 등\n\n\n\n\n0\n\n\n\n\n홈페이지 정보 만족도홈페이지 홍보, 작품소개 등\n\n\n\n\n0\n\n\n\n\n서비스 만족도티켓구매, 객석입장, 공연환경 등\n\n\n\n\n0\n\n\n\n\n\n관람 동반자\n\n혼자\n부부·연인\n부모·자녀\n동료·친구\n단체관람\n기타\n\n\n\n선택입력\n\n\n\n선택입력\n\n\n\n\n\n\n공개여부\n\n\n\n공개\n\n\n\n비공개\n(공개설정한 관람평은 작품 상세정보와 ‘참여·공감·이용>공감>관람평’에 게시됩니다.)\r\n                                            \n\n\n\n\n\n\n등록\n취소\n\n\n\n\n\n\n\n        \r          기관소개\r           \r          사이트맵\r           \r          정보공개\r           \r          이용약관 · 정책\r           \r          개인정보처리방침\r           \r          보도자료\r           \r          유실물\r           \r          1:1문의\r                 \r          대표자\r         \r          장형준\r         \r          사업자등록번호\r         \r          214-82-00264\r         \r          통신판매업신고\r        ...
#  Document(metadata={'source': 'https://www.sac.or.kr/site/main/show/show_view?SN=64761', 'title': '상세 정보 | 공연·전시 | 예술의전당', 'description': '예술의전당', 'language': 'ko'}, page_content='관련사이트\r           \r              국립발레단 \r               \r              국립오페라단 \r               \r              국립합창단 \r               \r              국립현대무용단 \r               \r              국립심포니오케스트라 \r               \r               예술의전당 후원회 \r               \r              문화체육관광부 \r                     ')]

# %%
for doc in docs:
    # print(doc)
    print(doc.page_content)
    print("---")
# Out:
# 상세 정보 | 공연·전시 | 예술의전당
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ENG
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         오페라하우스
#
#
#
#
#                         음악당
#
#
#
#
#                         미술관·박물관
#
#
#
#
#                         아카데미
#
#
#
#
#                         방문·이용
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 	                   	로그인
#
#
# 	                    회원가입
#
#
# 공연·전시오페라하우스음악당미술관·박물관연간일정오늘의 공연·전시진행/예정 프로그램SAC 기획 프로그램패키지티켓오픈공지당일할인티켓예매·취소 안내서예아카이브아카데미아카데미 안내수강신청오디션신청나의강좌온라인 사군자아카데미 공지사항아카데미 FAQ방문·이용공간소개오시는 길·주차안내편의서비스입점매장전당소식고객센터세계음악분수(선곡표)포스트/웹진/매거진관람평관람예절SAC 투어예술의전당 SNS대관안내공간별 대관안내입장권 운영안내회원서비스로그인회원가입멤버십이벤트기관소개기관소개 메인예술의전당 소개특별사업정보공개후원하기마이페이지티켓예매내역강좌신청내역마이찜참여와활동개인정보관리나의멤버십후원회회원탈퇴
# 공연·전시오페라하우스음악당미술관·박물관연간일정오늘의 공연·전시진행/예정 프로그램SAC 기획 프로그램패키지티켓오픈공지당일할인티켓예매·취소 안내서예아카이브아카데미아카데미 안내아카데미메인인문·감상미술실기서화어린이음악영재키즈클래식수강신청오디션신청나의강좌온라인 사군자아카데미 공지사항아카데미 FAQ방문·이용공간소개공간안내공연장전시장공연영상스튜디오-실감야외공간홍보관(@700)사이버투어오시는 길·주차안내편의서비스공연장 편의서비스전시장 편의서비스장애인·국가유공자 이용안내입점매장음식점쇼핑전당소식공지사항보도자료채용공고고객센터서비스플라자유실물센터FAQ1:1문의하기세계음악분수(선곡표)포스트/웹진/매거진관람평최대 별점 공연/전시최신순평점 높은순관람예절SAC 투어예술의전당 SNS대관안내공간별 대관안내오페라하우스음악당미술관·박물관공연영상스튜디오-실감기타 행사공간 및 촬영장소입장권 운영안내입장권 운영안내공간별 특이사항 및 좌석 안내공연·전시 홍보 서비스 안내배너광고 신청 안내회원서비스로그인회원가입멤버십이벤트기관소개기관소개 메인예술의전당 소개인사말역사운영이념조직CI소개협력기관후원회특별사업SAC ON SCREEN객석기부문화햇살사업정보공개정보공개안내사전정보공표비공개 대상정보공공데이터 개방경영공시사업실명제사업실명제운영보고서기부금 활용 내역후원하기마이페이지티켓예매내역강좌신청내역수강신청오디션내역수강생정보마이찜참여와활동개인정보관리나의멤버십후원회회원탈퇴
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 검색하기
#
#
#
#
#
#
#
#
#
# 닫기
#
#
#
#
#
#
#
#
#
#
# 오늘의행사
#
#
#
#
# 챗봇
#
#
#
#
# TOP
#
#
#
#
#
#
#
#
#
#
#
#
#
# 찜하기
# 공동주최
#
#
#               	 비욘드 더 스크림
#                 에드바르 뭉크
#
#
# 기간
#
#
#
#                             2024-05-22(수) ~ 2024-09-19(목)
#
#
#
# 시간10:00 ~ 19:00 (※ 매주 월요일 휴관)
# 장소
#
#                             한가람미술관 제1전시실,  제2전시실
#
#
# 입장연령전체관람
# 전시입장마감시간18:10
# 가격성인 20,000원 / 청소년,어린이 15,000원
# 주최서울신문사, KBS미디어, 예술의전당
# 후원문화체육관광부, 주한 노르웨이 대사관
# 문의070-8843-2024
#
# #에드바르뭉크  #비욘드더스크림  #120주년  #절규  #예술의전당  #뭉크
#
#
#
#
#
#
#
# 예매
#
#
#
#
#
#
#
#
#
#
# 공연·전시공연·전시아카데미방문·이용대관안내회원서비스기관소개마이페이지이용안내상세 정보오페라하우스음악당미술관·박물관연간일정오늘의 공연·전시진행/예정 프로그램SAC 기획 프로그램패키지티켓오픈공지당일할인티켓예매·취소 안내서예아카이브
#
#
# 국EN
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   >  공연/전시  >  진행·예정 프로그램
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 작품소개
# 할인정보
# 장소안내
# 관람평(1)
# 예매안내
#
#
#
#
#
#
#
#
#  노르웨이의 국민화가이자 표현주의의 선구자 에드바르 뭉크(1863-1944)의 작품 140점을 소개하는
#  아시아 최대 규모 회고전이 5월 22일부터 9월 19일까지 예술의전당 한가람미술관 1층에서 열립니다. ※ 현장에서 티켓 수령 시 할인에 해당하는 증빙자료(학생증, 신분증, 복지카드, 유공자증 등)를 제시하지 못할경우 차액 지불 후 전시 관람 가능  [예술의전당 유료회원] 성인 18,000원 / 청소년, 어린이: 13,000원 - 골드 · 블루· 그린 · 예술의전당 우리V카드 회원 (1인 2매)
#   [특별할인] 1인 입장권: 10,000원 - 65세 이상  - 장애인 복지카드 소지자 (1급~3급/중증) 본인 및 동반 1인  - 장애인 복지카드 소지자 (4급~6급/경증) 본인  - 국가유공자증, 의상자(1~2급)증 / 소지자 본인   - 유족증 (국가유공자,의사자), 의상자(3급이하)증 / 소지자 본인   [현장할인] - 군경소방관 본인 및 동반 1인 30% 할인
#
#
#
#
#
#
#
#
# 소개
# 공간 평면도
#
#
#
#
#
#
#
# 본관 전체 3층 총 6개 전시실
#
# 10:00 ~ 19:00
# 매주월요일 휴관
#
#
#
#
#
#
#
#
#
# 한가람미술관예술의전당에서 진행되는 다른 공간들 보다 편안하게 즐길 수 있는 열린 공간
# 1990년에 문을 연 한가람미술관은 조형예술 전시를 위한 최적의 공간이다. 2003년 리노베이션을 거쳐 최신의 설비로 재탄생 하였다. 지하 1층 지상 3층 건물에 6개의 전시장과 수장고를 가지고 있으며,
# 자연채광에 가까운 광천정 시스템으로 편안한 관람 분위기를 조성한다. 매년 50여 건이 넘는 전시행사가 개최되고 있으며
# 그 내용은 고대문명을 소개하는 전시회부터 현대 미술까지 아우르고 있다. 예술의전당이 기획하여 주최한 주요 전시는
# <반 아파르트헤이트전>, <유럽공동체신진작가전>, <칸딘스키와 아방가르드전>, <고대 이집트 문명전>,
# <고대 메소포타미아 문명전>, <램브란트판화전>, <밀레와 바르비종파 거장전>, <오르세미술관 한국특별전>,
# <프랑스 국립 베르사이유 특별전>, <스키타이 황금문명전>, <쿠사마 야요이전>, <페르난도 보테로전>, <니키 드 생팔전> 등이 있다. 공간평면도
#
#
# 1층
# 2층
# 3층
#
#
#
#
#
#
#
# 한가람미술관 편의시설
#
#
#
#
#
#
# 안내데스크
# 미술관 1층에 위치하고 있으며휠체어, 유모차가 준비되어 있습니다. 에드바르 뭉크에 대한 관람평을 적어주세요.
# ---
# ※ 저속한 표현, 타인의 명예훼손, 광고성 게시물 등은 통보 없이 삭제할 수 있음을 양지하여 주십시오.※ 등록된 관람평의 수정과 삭제는 마이페이지 > 참여와활동 > 관람평 에서 가능합니다. 관람평쓰기
#
#
#
#
#
#
#
#
#
#
#
#
#
# happydanuk***
# 2024.07.21(일)
#
#
# 작품들은 최고 관람진행은 바보!! 6시50분까지 오디오반납하라고 계속 소리 고래고래 지름. 안에 진행요원들 많던데 입구에서 수거를 하던가 퇴근을 좀 늦게 하던가! 너무 짜증났음!! 1
#
#
#
#
#
#
#
# 예매 및 환불·변경안내
# 예술의전당은 초등학생 이상부터 공연 관람이 가능하며, 관람 연령 증빙이 어려울 경우 티켓 소지 여부 및 보호자의 동반 여부와 관계 없이 입장이 불가능합니다. (단, 어린이 대상 공연은 제외)
#
# 승용차 이용 시 주차장이 혼잡하여 공연장 정시 입장이 어려울 수 있으니, 대중교통을 이용해 주시기 바랍니다. (주차장 혼잡으로 인한 공연장 입장 지연 시 피해보상(티켓교환 및 환불)불가)
#
# 온라인(PC,모바일) 예매의 경우 1회 10매까지 구매 가능합니다. 반복하여 예매하기 불편하거나 단체 티켓예매를 원하시면 서비스플라자 (1668-1352)를 이용해 주시기 바랍니다. 티켓은 유가증권이므로 분실하였을 경우 재발행 되지 않으며 환불 및 변경이 불가하오니 보관에 유의해주시기 바랍니다. 지정예매처를 통하지 않고 개인적으로 양도 양수한 티켓에 대해 예술의전당은 책임을 지지 않습니다. 공연, 전시에 따라 예매, 환불 및 환불수수료 정책이 상이할 경우 상세페이지에 별도 공지하며 해당 공지는 위 내용보다 우선합니다. 반드시 상세페이지를 확인 부탁드립니다. 환불·변경 수수료
#
# 환불·변경 수수료
#
#
#
#
#
#
#
#
# 구분
# 환불수수료
# 비고
#
#
#
#
# 관람일 10일 전
# 전액 환불
#
#
#
# 관람일 9일~1일 전
# 티켓금액의 10%
# 관람일 3일 전 예매건에 한해
# 			예매당일 환불할 경우
# 			별도의 수수료 없이 환불 가능
# (전화 : 20:00까지 /
# 			방문 : 화~일 20:00까지, 월 18:00까지 /
# 			인터넷 23:59까지)
#
#
# 관람 당일
# 전당기획공연
# 티켓금액의 90%
# 공연시작 2시간 전까지
# 			(현장매표소 환불 불가)
#
#
# 대관공연
# 환불 불가
# 관람일 1일 전까지 가능
#
#
#
#
#
#
# ※ 전시 상품 취소수수료 규정
# - 전시 회차상품 : 예술의전당 대관 공연 기준 수수료 적용
# - 전시 상시상품 : 예매 후 7일까지 미부과, 8일부터 10% 부과
#
# 티켓예매 시 결제수단
#
#
#  신용카드
# 관람당일까지 사용 가능
#
# * 온라인(PC/모바일) 예매
# * 관람당일 현장매표소
# * 서비스플라자 방문구매
#
#
#  무통장(가상계좌입금)
# 관람일 4일까지 사용 가능
#
# * 홈페이지(PC/모바일) 예매
#
#
#
#
# 결제수단별 환불처리 ※ 티켓예매시 사용한 결제수단으로만 환불됩니다. 신용카드
# 카드사 승인취소
#
# * 취소요청 후 4~5일내 취소
# * 카드사환불기준에따라다름
# * 체크카드 동일
# * 취소수수료는 재승인 필요
#
#
#  무통장(가상계좌입금)
# 예매자명의 계좌로 환급
#
# * 취소요청 후 2일내 환급
# * 은행 영업일 기준
# * 실시간 계좌이체 불가
# * 취소수수료는 제외하고 환급
#
#
#
#
#
# 예매취소 방법안내
#
#
#  홈페이지 예매
# - [ 마이페이지 > 티켓예매내역 ] 에서 직접 예매내역 조회 후 취소
# 	- 서비스플라자(1668-1352)를 통해 예매 취소 요청
#
#  전화 예매
# [ 마이페이지 > 티켓예매내역 ] 에서 직접 취소하거나
# 	서비스플라자(1668-1352)를 통해 취소 요청
#
#  예매 후 티켓 소지하고 있는 경우(방문예매, 우편배송 등)
# 해당공연 관람일 1일전까지 비타민스테이션 서비스플라자로 직접 방문하여 티켓을 반납 하여야만 환불 가능
# 	방문 가능시간 (월- 09:00~18:00 / 화~일- 09:00~20:00)
# 	(자세한 문의는 고객센터로 문의 요망 : 1668-1352, 09:00~20:00)
#
#
# ※ 부분취소
#
# 기본적으로 부분취소 가능합니다. 단, 기프트 카드 등을 사용하여 결제한 경우에는 부분취소를 하실 수 없고, 전체취소만 가능합니다. 1+1, 3인 할인 등 특정 매수 제한이 있는 할인권종으로 예매하신 경우 부분취소를 하실 수 없고, 전체취소만 가능합니다. 예매 내역에 따라 부분 취소 가능여부가 달라지오니 서비스플라자 콜센터(1668-1352)로 문의해 주시기 바랍니다. 티켓수령 안내
#
#
#  현장매표소
#
# * 공연당일 수령
# * 공연시작 1시간 30분전부터 중간휴식시간까지
# * 중간휴식이 없는 경우 공연시작 후 30분까지 운영
#
#
#  서비스플라자
#
# * 위치 : 비타민스테이션 내
# * 운영시간 : 09:00~20:00, 월요일의 경우 09:00~18:00
# * 문의 : 1668-1352(연중무휴)
# * 타예매처 티켓 수령불가
#
#
#  우편 배송 신청
#
# * 배송신청 : 온라인,전화예매 시 공연일 14일전까지
# * 이용료 : 1회 배송시 3,200원 선결제
# * 수령일 : 배송신청 후 5일 이내 수령 (영업일 기준)
#
#
#
#
#  티켓수령시 유의사항
#
# 증빙이 필요한 할인(쿠폰, 장애인 및 국가유공자, 학생, 문화릴레이, 당일할인티켓 등)의 경우, 본인이 직접 증빙자료를 제시하여야 수령이 가능합니다. 제시하지 못할 경우, 할인 받은 만큼 차액을 지불하시면 관람이 가능합니다. 공연 시작 직전에는 현장매표소가 매우 혼잡하오니 되도록 공연 30분전까지 티켓을 수령 해주시기 바랍니다. 목록보기
#
#
#
#
#
# 관람평쓰기
#
#
#
#
# 관람평쓰기
#
#
#
#
#
#
# 작성자
# 비회원손님 2024.08.26(월)
#
#
# 작품명
# 에드바르 뭉크
#
#
# 종합평점 *
#
#
#
#
#
# 0
#
#
#
#
#
# 관람평
#
#
#
# 내용
#
# (0 / 최대 1000자) 관람평은 1000자까지만 등록이 가능합니다. 작품만족도작품성, 완성도, 무대, 출연자 등
#
#
#
#
# 0
#
#
#
#
# 관람비용 만족도가격, 할인 등
#
#
#
#
# 0
#
#
#
#
# 홈페이지 정보 만족도홈페이지 홍보, 작품소개 등
#
#
#
#
# 0
#
#
#
#
# 서비스 만족도티켓구매, 객석입장, 공연환경 등
#
#
#
#
# 0
#
#
#
#
#
# 관람 동반자
#
# 혼자
# 부부·연인
# 부모·자녀
# 동료·친구
# 단체관람
# 기타
#
#
#
# 선택입력
#
#
#
# 선택입력
#
#
#
#
#
#
# 공개여부
#
#
#
# 공개
#
#
#
# 비공개
# (공개설정한 관람평은 작품 상세정보와 ‘참여·공감·이용>공감>관람평’에 게시됩니다.)
#
#
#
#
#
#
#
# 등록
# 취소
#
#
#
#
#
#
#
#         copyrightⓒ2023 Seoul Arts Center. All rights reserved.
# ---
#                       원회
# ---
